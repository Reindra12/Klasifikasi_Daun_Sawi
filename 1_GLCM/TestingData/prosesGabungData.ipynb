# %%
import pandas as pd
path1 = 'F:/applications/python/Klasifikasi_Daun_Sawi/1_GLCM/TestingData/EkstraksiDaunTANPAHAMA_Testing.csv'
path2 = 'F:/applications/python/Klasifikasi_Daun_Sawi/1_GLCM/TestingData/EkstraksiDaunADAHAMA_Testing.csv'

datalengkap = pd.concat(
    map(pd.read_csv, [path1, path2]), ignore_index=True)

datalengkap.to_csv(r'hasilGLCMdataTesting.csv',index=False)
datalengkap
# Out:
#        Citra  energy_0  homogenity_0  entrophy_0  contrast_0  energy_45  \
# 0    401.png  0.002990     11.476603    6.494680   10.476603   0.002110
# 1    402.png  0.002303      6.354390    6.602114    5.354390   0.001512
# 2    403.png  0.002125      9.262720    6.656178    8.262720   0.001531
# 3    404.png  0.003164      4.226832    6.337473    3.226832   0.001955
# 4    405.png  0.001978      7.612518    6.700894    6.612518   0.001547
# ..       ...       ...           ...         ...         ...        ...
# 195  496.png  0.001088     50.775371    7.613240   49.775371   0.000716
# 196  497.png  0.000741     36.961629    7.810223   35.961629   0.000534
# 197  498.png  0.000854     41.176505    7.729564   40.176505   0.000561
# 198  499.png  0.001230     36.029123    7.377756   35.029123   0.000869
# 199  500.png  0.000539     37.186936    8.022883   36.186936   0.000380
#
#      homogenity_45  entrophy_45  contrast_45  energy_90  homogenity_90  \
# ...
