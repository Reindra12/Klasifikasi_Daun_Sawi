# %%
import pandas as pd
path1 = 'F:/applications/python/Klasifikasi_Daun_Sawi/1_GLCM/TrainingData/EkstraksiDaunTANPAHAMA_Training.csv'
path2 = 'F:/applications/python/Klasifikasi_Daun_Sawi/1_GLCM/TrainingData/EkstraksiDaunADAHAMA_Training.csv'

datalengkap = pd.concat(
    map(pd.read_csv, [path1, path2]), ignore_index=True)

datalengkap.to_csv(r'hasilGLCMdataTraining.csv',index=False)
datalengkap
# Out:
#        Citra  energy_0  homogenity_0  entrophy_0  contrast_0  energy_45  \
# 0      1.png  0.001033     17.871236    7.360620   16.871236   0.000736
# 1     10.png  0.001623     14.459853    7.046904   13.459853   0.001078
# 2    100.png  0.002920      5.739939    6.398762    4.739939   0.001843
# 3    101.png  0.003383      3.999953    6.200812    2.999953   0.002321
# 4    102.png  0.003391      5.682657    6.217107    4.682657   0.002490
# ..       ...       ...           ...         ...         ...        ...
# 794   95.png  0.001482     13.655299    7.068650   12.655299   0.001012
# 795   96.png  0.001087     25.045009    7.382943   24.045009   0.000852
# 796   97.png  0.002034     10.651257    6.940028    9.651257   0.001616
# 797   98.png  0.001658     10.372622    7.010297    9.372622   0.001292
# 798   99.png  0.001925      8.160298    6.899217    7.160298   0.001531
#
#      homogenity_45  entrophy_45  contrast_45  energy_90  homogenity_90  \
# ...
